# %%
using Pkg
Pkg.add("Gadfly")
Pkg.add("Knet")
# Out:
#    Resolving package versions...
#    Installed FFTW ────────────────────── v1.7.1
#    Installed Media ───────────────────── v0.5.0
#    Installed IntelOpenMP_jll ─────────── v2023.2.0+0
#    Installed DiffEqBase ──────────────── v6.128.1
#    Installed SpecialFunctions ────────── v2.3.1
#    Installed BandedMatrices ──────────── v0.17.36
#    Installed Loess ───────────────────── v0.6.1
#    Installed Ratios ──────────────────── v0.4.5
#    Installed Hexagons ────────────────── v0.2.0
#    Installed MKL_jll ─────────────────── v2023.2.0+0
#    Installed Gadfly ──────────────────── v1.4.0
#    Installed JLLWrappers ─────────────── v1.5.0
#    Installed AbstractFFTs ────────────── v1.5.0
#    Installed MLJBase ─────────────────── v0.21.14
#    Installed OrdinaryDiffEq ──────────── v6.54.0
#    Installed KernelDensity ───────────── v0.6.7
#    Installed FFTW_jll ────────────────── v3.3.10+0
#    Installed CoupledFields ───────────── v0.2.0
#    Installed MLJModelInterface ───────── v1.9.1
#    Installed IndirectArrays ──────────── v1.0.0
#    Installed Compose ─────────────────── v0.9.5
#    Installed RuntimeGeneratedFunctions ─ v0.5.12
#    Installed IterTools ───────────────── v1.8.0
#    Installed Krylov ──────────────────── v0.9.3
#    Installed HostCPUFeatures ─────────── v0.1.16
#    Installed AxisAlgorithms ──────────── v1.0.1
#    Installed WoodburyMatrices ────────── v0.5.5
#    Installed Juno ────────────────────── v0.8.4
#    Installed RecursiveFactorization ──── v0.2.20
#    Installed Interpolations ──────────── v0.14.7
#     Updating `C:\Users\Kan\.julia\environments\v1.9\Project.toml`
#   [c91e804a] + Gadfly v1.4.0
#     Updating `C:\Users\Kan\.julia\environments\v1.9\Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [13072b0f] + AxisAlgorithms v1.0.1
#   [aae01518] ↑ BandedMatrices v0.17.35 ⇒ v0.17.36
#   [a81c6b42] + Compose v0.9.5
#   [d38c429a] + Contour v0.6.2
#   [7ad07ef1] + CoupledFields v0.2.0
#   [2b5f629d] ↑ DiffEqBase v6.128.0 ⇒ v6.128.1
#   [7a1cc6ca] + FFTW v1.7.1
#   [c91e804a] + Gadfly v1.4.0
#   [42e2da0e] + Grisu v1.0.2
#   [a1b4810d] + Hexagons v0.2.0
#   [3e5b6fbb] ↑ HostCPUFeatures v0.1.15 ⇒ v0.1.16
#   [9b13fd28] + IndirectArrays v1.0.0
#   [a98d9a8b] + Interpolations v0.14.7
#   [c8e1da08] + IterTools v1.8.0
#   [692b3bcd] ↑ JLLWrappers v1.4.1 ⇒ v1.5.0
#   [e5e0dc1b] + Juno v0.8.4
#   [5ab0869b] + KernelDensity v0.6.7
#   [ba0b0d4f] ↑ Krylov v0.9.2 ⇒ v0.9.3
#   [4345ca2d] + Loess v0.6.1
#   [a7f614a8] ↑ MLJBase v0.21.13 ⇒ v0.21.14
#   [e80e1ace] ↑ MLJModelInterface v1.8.0 ⇒ v1.9.1
#   [442fdcdd] + Measures v0.3.2
#   [e89f7d12] + Media v0.5.0
#   [1dea7af3] ↑ OrdinaryDiffEq v6.53.4 ⇒ v6.54.0
#   [c84ed2f1] + Ratios v0.4.5
#   [f2c3362d] ↑ RecursiveFactorization v0.2.19 ⇒ v0.2.20
#   [7e49a35a] ↑ RuntimeGeneratedFunctions v0.5.11 ⇒ v0.5.12
#   [992d4aef] + Showoff v1.0.3
#   [276daf66] ↑ SpecialFunctions v2.3.0 ⇒ v2.3.1
# ⌅ [2913bbd2] ↓ StatsBase v0.34.0 ⇒ v0.33.21
#   [efce3f68] + WoodburyMatrices v0.5.5
#   [f5851436] + FFTW_jll v3.3.10+0
#   [1d5cc7b8] + IntelOpenMP_jll v2023.2.0+0
#   [856f044c] + MKL_jll v2023.2.0+0
#   [4af54fe1] + LazyArtifacts
#   [9abbd945] + Profile
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ Contour
#   ✓ IndirectArrays
#   ✓ AbstractFFTs
#   ✓ WoodburyMatrices
#   ✓ Measures
#   ✓ IterTools
#   ✓ Grisu
#   ✓ Hexagons
#   ✓ RuntimeGeneratedFunctions
#   ✓ Ratios
#   ✓ Loess
#   ✓ MLJModelInterface
#   ✓ Media
#   ✓ JLLWrappers
#   ✓ HostCPUFeatures
#   ✓ Krylov
#   ✓ StatsBase
#   ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#   ✓ AbstractFFTs → AbstractFFTsTestExt
#   ✓ AxisAlgorithms
#   ✓ Showoff
#   ✓ Ratios → RatiosFixedPointNumbersExt
#   ✓ Compose
#   ✓ Juno
#   ✓ OpenSSL_jll
#   ✓ libsodium_jll
#   ✓ Rmath_jll
#   ✓ IntelOpenMP_jll
#   ✓ Sundials_jll
#   ✓ FFTW_jll
#   ✓ OpenSpecFun_jll
#   ✓ LatinHypercubeSampling
#   ✓ CoupledFields
#   ✓ Interpolations
#   ✓ OpenSSL
#   ✓ ZeroMQ_jll
#   ✓ Rmath
#   ✓ SpecialFunctions
#   ✓ BandedMatrices
#   ✓ HTTP
#   ✓ ZMQ
#   ✓ LevyArea
#   ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#   ✓ DiffRules
#   ✓ DualNumbers
#   ✓ MKL_jll
#   ✓ BandedMatrices → BandedMatricesSparseArraysExt
#   ✓ OpenML
#   ✓ ArrayInterface → ArrayInterfaceBandedMatricesExt
#   ✓ IJulia
#   ✓ HypergeometricFunctions
#   ✓ StaticArrayInterface
#   ✓ FiniteDiff
#   ✓ ForwardDiff
#   ✓ RecursiveArrayTools
#   ✓ SciMLOperators
#   ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#   ✓ StatsFuns
#   ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ✓ CloseOpenIntervals
#   ✓ LayoutPointers
#   ✓ FiniteDiff → FiniteDiffStaticArraysExt
#   ✓ FiniteDiff → FiniteDiffBandedMatricesExt
#   ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   ✓ Roots → RootsForwardDiffExt
#   ✓ SparseDiffTools
#   ✓ FFTW
#   ✓ StatsFuns → StatsFunsChainRulesCoreExt
#   ✓ StrideArraysCore
#   ✓ SciMLBase
#   ✓ PreallocationTools
#   ✓ NLSolversBase
#   ✓ Distributions
#   ✓ Polyester
#   ✓ LineSearches
#   ✓ Distributions → DistributionsChainRulesCoreExt
#   ✓ FastBroadcast
#   ✓ NLsolve
#   ✓ Optim
#   ✓ ScientificTypes
#   ✓ KernelDensity
#   ✓ VectorizationBase
#   ✓ CategoricalDistributions
#   ✓ DiffEqBase
#   ✓ SLEEFPirates
#   ✓ Gadfly
#   ✓ MLJModels
#   ✓ DiffEqBase → DiffEqBaseDistributionsExt
#   ✓ MLJBase
#   ✓ JumpProcesses
#   ✓ DiffEqCallbacks
#   ✓ SciMLNLSolve
#   ✓ SimpleNonlinearSolve
#   ✓ Sundials
#   ✓ DiffEqNoiseProcess
#   ✓ MLJIteration
#   ✓ BoundaryValueDiffEq
#   ✓ MLJTuning
#   ✓ MLJEnsembles
#   ✓ SteadyStateDiffEq
#   ✓ MLJ
#   ✓ LoopVectorization
#   ✓ LoopVectorization → SpecialFunctionsExt
#   ✓ LoopVectorization → ForwardDiffExt
#   ✓ TriangularSolve
#   ✓ RecursiveFactorization
#   ✓ LinearSolve
#   ✓ LinearSolve → LinearSolveMKLExt
#   ✓ NonlinearSolve
#   ✓ OrdinaryDiffEq
#   ✓ DelayDiffEq
#   ✓ StochasticDiffEq
#   ✓ DifferentialEquations
#   113 dependencies successfully precompiled in 472 seconds. 154 already precompiled.
#   5 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#   1 dependency had warnings during precompilation:
# ┌ MKL_jll [856f044c-d86e-5d09-b602-aeab76dc8ba7]
# │   Downloading artifact: MKL
# └
#    Resolving package versions...
#    Installed BFloat16s ────────── v0.2.0
#    Installed TimerOutputs ─────── v0.5.23
#    Installed ImageMagick ──────── v1.3.0
#    Installed AutoGrad ─────────── v1.2.5
#    Installed GPUArrays ────────── v8.8.1
#    Installed JLD2 ─────────────── v0.4.33
#    Installed NNlib ────────────── v0.8.21
#    Installed LLVM ─────────────── v4.17.1
#    Installed UnsafeAtomicsLLVM ── v0.1.1
#    Installed Graphics ─────────── v1.1.2
#    Installed MappedArrays ─────── v0.4.2
#    Installed PaddedViews ──────── v0.5.12
#    Installed ImageMagick_jll ──── v6.9.10-12+3
#    Installed MosaicViews ──────── v0.3.4
#    Installed Libtiff_jll ──────── v4.4.0+0
#    Installed StackViews ───────── v0.1.1
#    Installed LLVMExtra_jll ────── v0.0.18+0
#    Installed UnsafeAtomics ────── v0.2.1
#    Installed KernelAbstractions ─ v0.9.8
#    Installed Atomix ───────────── v0.1.0
#    Installed ImageCore ────────── v0.9.4
#    Installed GPUCompiler ──────── v0.17.3
#    Installed Knet ─────────────── v1.4.10
#    Installed CUDA ─────────────── v3.13.1
#     Updating `C:\Users\Kan\.julia\environments\v1.9\Project.toml`
#   [1902f260] + Knet v1.4.10
#     Updating `C:\Users\Kan\.julia\environments\v1.9\Manifest.toml`
#   [a9b6321e] + Atomix v0.1.0
#   [6710c13c] + AutoGrad v1.2.5
# ⌅ [ab4f0b2a] + BFloat16s v0.2.0
# ⌅ [052768ef] + CUDA v3.13.1
# ⌅ [c3611d14] + ColorVectorSpace v0.9.10
#   [5789e2e9] + FileIO v1.16.1
#   [0c68f7d7] + GPUArrays v8.8.1
# ⌅ [61eb1bfa] + GPUCompiler v0.17.3
#   [a2bd30eb] + Graphics v1.1.2
# ⌅ [a09fc81d] + ImageCore v0.9.4
#   [6218d12a] + ImageMagick v1.3.0
#   [033835bb] + JLD2 v0.4.33
#   [63c18a36] + KernelAbstractions v0.9.8
#   [1902f260] + Knet v1.4.10
# ⌅ [929cbde3] + LLVM v4.17.1
#   [dbb5928d] + MappedArrays v0.4.2
#   [e94cdb99] + MosaicViews v0.3.4
# ⌅ [872c559c] + NNlib v0.8.21
#   [5432bcbf] + PaddedViews v0.5.12
#   [cae243ae] + StackViews v0.1.1
#   [62fd8b95] + TensorCore v0.1.1
#   [a759f4b9] + TimerOutputs v0.5.23
#   [013be700] + UnsafeAtomics v0.2.1
# ⌃ [d80eeb9a] + UnsafeAtomicsLLVM v0.1.1
# ⌅ [c73af94c] + ImageMagick_jll v6.9.10-12+3
#   [aacddb02] + JpegTurbo_jll v2.1.91+0
#   [88015f11] + LERC_jll v3.0.0+1
# ⌅ [dad2f222] + LLVMExtra_jll v0.0.18+0
# ⌅ [89763e89] + Libtiff_jll v4.4.0+0
#   [3161d3a3] + Zstd_jll v1.5.5+0
#   [b53b4c65] + libpng_jll v1.6.38+0
#         Info Packages marked with ⌃ and ⌅ have new versions available, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ TensorCore
#   ✓ BFloat16s
#   ✓ MappedArrays
#   ✓ UnsafeAtomics
#   ✓ libpng_jll
#   ✓ LERC_jll
#   ✓ TimerOutputs
#   ✓ JpegTurbo_jll
#   ✓ LLVMExtra_jll
#   ✓ Zstd_jll
#   ✓ StackViews
#   ✓ FileIO
#   ✓ Graphics
#   ✓ PaddedViews
#   ✓ Atomix
#   ✓ ColorVectorSpace
#   ✓ AutoGrad
#   ✓ Libtiff_jll
#   ✓ MosaicViews
#   ✓ LLVM
#   ✓ ImageMagick_jll
#   ✓ JLD2
#   ✓ UnsafeAtomicsLLVM
#   ✓ GPUArrays
#   ✓ KernelAbstractions
#   ✓ GPUCompiler
#   ✓ ImageCore
#   ✓ NNlib
#   ✓ ImageMagick
#   ✓ CUDA
#   ✓ ArrayInterface → ArrayInterfaceCUDAExt
#   ✓ FiniteDiff
#   ✓ StaticArrayInterface
#   ✓ SciMLOperators
#   ✓ RecursiveArrayTools
#   ✓ FiniteDiff → FiniteDiffStaticArraysExt
#   ✓ FiniteDiff → FiniteDiffBandedMatricesExt
# InterruptException:
#
# Stacktrace:
#   [1] try_yieldto(undo::typeof(Base.ensure_rescheduled))
#     @ Base .\task.jl:920
#   [2] wait()
#     @ Base .\task.jl:984
#   [3] wait(c::Base.GenericCondition{Base.Threads.SpinLock}; first::Bool)
#     @ Base .\condition.jl:130
#   [4] wait(c::Base.GenericCondition{Base.Threads.SpinLock})
#     @ Base .\condition.jl:125
#   [5] _wait(t::Task)
#     @ Base .\task.jl:308
#   [6] wait(t::Task)
#     @ Base .\task.jl:347
#   [7] (::Pkg.API.var"#handle_interrupt#268"{Base.Event, ReentrantLock, IJulia.IJuliaStdio{Base.PipeEndpoint}})(err::InterruptException, in_printloop::Bool)
#     @ Pkg.API C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\API.jl:1295
#   [8] (::Pkg.API.var"#handle_interrupt#268"{Base.Event, ReentrantLock, IJulia.IJuliaStdio{Base.PipeEndpoint}})(err::InterruptException)
#     @ Pkg.API C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\API.jl:1293
#   [9] precompile(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; internal_call::Bool, strict::Bool, warn_loaded::Bool, already_instantiated::Bool, timing::Bool, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Pkg.API C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\API.jl:1498
#  [10] precompile
#     @ C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\API.jl:1115 [inlined]
#  [11] #_auto_precompile#7
#     @ C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\Pkg.jl:790 [inlined]
#  [12] _auto_precompile (repeats 2 times)
#     @ C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\Pkg.jl:788 [inlined]
#  [13] add(pkgs::Vector{Pkg.Types.PackageSpec}; io::IJulia.IJuliaStdio{Base.PipeEndpoint}, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Pkg.API C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\API.jl:157
#  [14] add(pkgs::Vector{Pkg.Types.PackageSpec})
#     @ Pkg.API C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\API.jl:145
#  [15] #add#25
#     @ C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\API.jl:144 [inlined]
#  [16] add
#     @ C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\API.jl:144 [inlined]
#  [17] #add#24
#     @ C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\API.jl:143 [inlined]
#  [18] add(pkg::String)
#     @ Pkg.API C:\Users\Kan\AppData\Local\Programs\Julia-1.9.2\share\julia\stdlib\v1.9\Pkg\src\API.jl:143
#  [19] top-level scope
#     @ In[1]:3

# %%
using DataFrames, Gadfly, Knet
println("### READING DATA ###")
data = readtable("OnlineNewsPopularity.csv", separator = ',')[:, 3:end]; # first 2 columns have no values
println((:data_shape, size(data)))
println("")

# %%
println("# Preparing Data:")
println("* scaling X, log Y, and split data into train and test")
x = convert(Array{Float32}, data[:, 1:end-1]);
y = convert(Array{Float32}, data[end]);
# y = map(Float32, data[:, end])
x = x ./ sum(x, 1); # scale x
y = log.(y); # log y 
splits = round(Int, 0.1 * size(x, 1)); 
shuffled = randperm(size(x, 1));
xtrain, ytrain = [x[shuffled[splits + 1:end], :]', y[shuffled[splits + 1:end]]'];
xtest, ytest = [x[shuffled[1:splits], :]', y[shuffled[1:splits]]'];
println("# Check that both data are of the same distribution")
println(sum(ytrain) / length(ytrain), " , ", sum(ytest) / length(ytest))
println("")
println("# size of train and test data")
println(size(xtrain), size(xtest))
println("")

# %%
println("# Define the Model:")
println("* predict, loss, and train functions and initial coeffs and the intercept")
predict(w, x) = w[1] * x .+ w[2]; # linear regression equation ax + b
loss(w, x, y) = mean(abs2, y-predict(w, x)); # mean error
lossgradient = grad(loss); # lossgradient returns dw, the gradient of the loss

# %%
function train(w, data; lr = 0.25) # lr learning rate
    for (x, y) in data
        dw = lossgradient(w, x, y)
        for i in 1:length(w)
           w[i] -= lr * dw[i]
        end     
    end
    return w
end;
w = map(Array{Float32}, Any[0.1 * randn(1, 58), zeros(1, 1)]); # initial coefficients of 58 variables and the intercept
train_loss = [];
test_loss = [];
println("")
println("### FITTING THE MODEL ###")
for i in 1:10
	train(w, [(xtrain, ytrain)])
	append!(train_loss, loss(w, xtrain, ytrain))
	append!(test_loss, loss(w, xtest, ytest))
	println((:epoch, i, :train_loss, train_loss[i], :test_loss, test_loss[i]))
end
println("")

# %%
println("# plotting the loss of train and data")
trn = DataFrame(epoch = 1:10, train_loss = train_loss);
tst = DataFrame(epoch = 1:10, test_loss = test_loss);
df = join(trn, tst, on = :epoch) ;
df = melt(df, :epoch);
plt = plot(df, x = :epoch, y = :value, color = :variable, Geom.line);
draw(PNG("loss_plot.png", 6inch, 5inch), plt)
println("# a loss plot has been saved into your directory")
